# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.10.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from covid import Covid

covid = Covid()
covid.get_data()
# Out:
# [{'id': '177',
#   'country': 'US',
#   'confirmed': 9385324,
#   'active': 5447559,
#   'deaths': 232635,
#   'recovered': 3705130,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'last_update': 1604489090000},
#  {'id': '80',
#   'country': 'India',
#   'confirmed': 8313876,
#   'active': 533787,
#   'deaths': 123611,
#   'recovered': 7656478,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'last_update': 1604489090000},
#  {'id': '24',
#   'country': 'Brazil',
#   'confirmed': 5566049,
#   'active': 344856,
#   'deaths': 160496,
#   'recovered': 5060697,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'last_update': 1604489090000},
#  {'id': '142',
#   'country': 'Russia',
#   'confirmed': 1680579,
#   'active': 392389,
#   'deaths': 28996,
#   'recovered': 1259194,
#   'latitude': 61.524,
#   'longitude': 105.3188,
#   'last_update': 1604489090000},
#  {'id': '63',
#   'country': 'France',
#   'confirmed': 1461391,
#   'active': 1296627,
#   'deaths': 37492,
# ...

# %%
j=covid.get_data()

# %%
j[0]['country']
# Out:
# 'US'

# %%
type(j)
# Out:
# list

# %%
f=pd.DataFrame(j)

# %%
f
# Out:
#       id                country  confirmed   active  deaths  recovered  \
# 0    177                     US    9385324  5447559  232635  3705130.0
# 1     80                  India    8313876   533787  123611  7656478.0
# 2     24                 Brazil    5566049   344856  160496  5060697.0
# 3    142                 Russia    1680579   392389   28996  1259194.0
# 4     63                 France    1461391  1296627   37492   123664.0
# ..   ...                    ...        ...      ...     ...        ...
# 185  144  Saint Kitts and Nevis         19        0       0       19.0
# 186  157        Solomon Islands         13        9       0        4.0
# 187  187         Western Sahara         10        1       1        8.0
# 188  105             MS Zaandam          9        7       2        NaN
# 189  112       Marshall Islands          2        2       0        NaN
#
#       latitude   longitude    last_update
# 0    40.000000 -100.000000  1604489090000
# ...

# %%
f1=pd.read_csv('2014_World_GDP')
f1
# Out:
#             COUNTRY  GDP (BILLIONS) CODE
# 0       Afghanistan           21.71  AFG
# 1           Albania           13.40  ALB
# 2           Algeria          227.80  DZA
# 3    American Samoa            0.75  ASM
# 4           Andorra            4.80  AND
# ..              ...             ...  ...
# 217  Virgin Islands            5.08  VGB
# 218       West Bank            6.64  WBG
# 219           Yemen           45.45  YEM
# 220          Zambia           25.61  ZMB
# 221        Zimbabwe           13.74  ZWE
#
# [222 rows x 3 columns]

# %%
f1[f1['COUNTRY']=='United States']
# Out:
#            COUNTRY  GDP (BILLIONS) CODE
# 211  United States         17420.0  USA

# %%
f['country'][0]='United States'

# %%
f=f.rename(columns={'country':'COUNTRY'})

# %%
f
# Out:
#       id                COUNTRY  confirmed   active  deaths  recovered  \
# 0    177          United States    9385324  5447559  232635  3705130.0
# 1     80                  India    8313876   533787  123611  7656478.0
# 2     24                 Brazil    5566049   344856  160496  5060697.0
# 3    142                 Russia    1680579   392389   28996  1259194.0
# 4     63                 France    1461391  1296627   37492   123664.0
# ..   ...                    ...        ...      ...     ...        ...
# 185  144  Saint Kitts and Nevis         19        0       0       19.0
# 186  157        Solomon Islands         13        9       0        4.0
# 187  187         Western Sahara         10        1       1        8.0
# 188  105             MS Zaandam          9        7       2        NaN
# 189  112       Marshall Islands          2        2       0        NaN
#
#       latitude   longitude    last_update
# 0    40.000000 -100.000000  1604489090000
# ...

# %%
df=pd.merge(f,f1)

# %%
df
# Out:
#       id                COUNTRY  confirmed   active  deaths  recovered  \
# 0    177          United States    9385324  5447559  232635  3705130.0
# 1     80                  India    8313876   533787  123611  7656478.0
# 2     24                 Brazil    5566049   344856  160496  5060697.0
# 3    142                 Russia    1680579   392389   28996  1259194.0
# 4     63                 France    1461391  1296627   37492   123664.0
# ..   ...                    ...        ...      ...     ...        ...
# 172   70                Grenada         29        2       0       27.0
# 173   96                   Laos         24        1       0       23.0
# 174  144  Saint Kitts and Nevis         19        0       0       19.0
# 175  157        Solomon Islands         13        9       0        4.0
# 176  112       Marshall Islands          2        2       0        NaN
#
#       latitude   longitude    last_update  GDP (BILLIONS) CODE
# ...

# %%
data=dict(type='choropleth',
         locations=df['CODE'],
         text=df['COUNTRY'],
         z=df['confirmed'],
         colorbar={'title':'COVID CASES here below see the range and read the plot'},colorscale='ylorbr')

# %%
layout=dict(title='Covid cases by jyotir aditya kalra',geo=dict(showframe=False,projection={'type':'stereographic'}))

# %%
import plotly.graph_objs as go

# %%
c=go.Figure([data],layout)

# %%
iplot(c)
# Out:
# <div>                            <div id="90fb16a0-5a8f-4a67-8215-99a3db26b767" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90fb16a0-5a8f-4a67-8215-99a3db26b767")) {                    Plotly.newPlot(                        "90fb16a0-5a8f-4a67-8215-99a3db26b767",                        [{"colorbar": {"title": {"text": "COVID CASES here below see the range and read the plot"}}, "colorscale": [[0.0, "rgb(255,255,229)"], [0.125, "rgb(255,247,188)"], [0.25, "rgb(254,227,145)"], [0.375, "rgb(254,196,79)"], [0.5, "rgb(254,153,41)"], [0.625, "rgb(236,112,20)"], [0.75, "rgb(204,76,2)"], [0.875, "rgb(153,52,4)"], [1.0, "rgb(102,37,6)"]], "locations": ["USA", "IND", "BRA", "RUS", "FRA", "ESP", "ARG", "COL", "GBR", "MEX", "PER", "ITA", "ZAF", "IRN", "DEU",
# ...

# %%
plot(c)
# Out:
# 'temp-plot.html'
